# %%
# !pip install zenml["server"]
# !zenml up
# Out:
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---------------------------------------- 4.5/4.5 MB 38.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/525.6 kB ? eta -:--:--
#    ---------------------------------------- 525.6/525.6 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
# ...

# %%
# !zenml init
# Out:
# ⠋ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠋ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠹ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠸ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠼ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠴ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠦ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠧ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# ⠏ Initializing ZenML repository at c:\Users\aadit\Job
# Preparation\Project\Customer_Satisfaction.
#
# Creating database tables
# ...

# %%
# !zenml up
# Out:
# The `zenml up` command is deprecated and will be removed in a future release.
# Please use the `zenml login --local` command instead.
# Calling `zenml login --local`...
# Error: Running the ZenML server locally as a background process is not supported on Windows. Please use the `--blocking` flag to run the server in blocking mode, or run the server in a Docker container by setting `--docker` instead.
